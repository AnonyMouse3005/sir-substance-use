# %% [markdown]
# # SIR model

# %% [markdown]
# Here we calibrate a differentiable version of the SIR model.
# We use the exact same model as  https://ndlib.readthedocs.io/en/latest/reference/models/epidemics/SIR.html,
# but implemented in a differentiable way.

# %%
# from blackbirds.models.sir import SIR
from blackbirds.infer.vi import VI

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx
import normflows as nf
import pygtc

from sir_agents_torch_egonets_cal import SIR, simulate_and_observe_model
from loss import MMD

# %% [markdown]
# ## Generating synthetic true data

# %%
device = "cpu"

# %%
# generate a random graph
n_agents = 100
k, p = 10, 0.1
graph = networkx.watts_strogatz_graph(n_agents, k, p, seed=0)

# %%
n_timesteps = 100
gamma, rho, initial_fraction_infected = 0.15, 0.15, 0.1
model = SIR(graph, n_timesteps=n_timesteps, n_agents=n_agents, device=device)

# %%
# %%time
# the simulator takes as parameters the log10 of the fraction of initial cases, beta, and gamma parameters
# true_parameters = torch.tensor([gamma, rho, initial_fraction_infected], device=device)
true_parameters = torch.log10(torch.tensor([gamma, rho, initial_fraction_infected], device=device))
data = model(true_parameters)
_, true_infected, true_recovered, true_states, true_ego_nets = data

# %%
# def map_states(states):
#     state_dict = {0: 'I', 1: 'S', 2: 'R'}  ## state S, I, R takes value of 1, 0, 2, respectively
#     return np.vectorize(state_dict.get)(states)

# true_states = map_states(true_states)

# %%
# def get_ego_nets(ego_nets_per_day, states_per_day, agent_sample):
#     G_per_day, y_per_day = [], []
#     for t in range(len(ego_nets_per_day)):
#         ego_nets, states = ego_nets_per_day[t], states_per_day[t]
#         G = []
#         curr = 0
#         for i in agent_sample:
#             node_ids = ego_nets.n_id[ego_nets.n_sub_batch == i]
#             ego_net = ego_nets.subgraph(node_ids)
#             g = torch_geometric.utils.to_networkx(ego_net, to_undirected=True)
#             networkx.set_node_attributes(g, {j: state for j, state in enumerate(states[node_ids])}, "state")
#             G.append(networkx.relabel_nodes(g, lambda x: x + curr))  # NOTE: relabel since node names need to be disjoint
#             curr += len(node_ids)
#         G = networkx.compose_all(G)
#         G_per_day.append(G)
#         # y_per_day.append(networkx.get_node_attributes(G, "state"))
#     return G_per_day

# %%
sample_ratio = 0.1
np.random.seed(0)
agent_sample = np.random.choice(n_agents, int(n_agents*sample_ratio), replace=False)
# agent_sample = np.arange(n_agents)
# true_ego_nets_subset = get_ego_nets(true_ego_nets, true_states, agent_sample)

# %%
f, ax = plt.subplots()
ax.plot(true_infected.cpu(), label = "active infected")
ax.set_xlabel("Time-step")
ax.plot(true_recovered.cpu(), label = "cumulative recovered")
ax.legend()

# %% [markdown]
# ## Approximating the posterior by a normalizing flow

# %% [markdown]
# We construct the flow using the normflows library (https://github.com/VincentStimper/normalizing-flows )

# %% [markdown]
# In this case we define Neural Spline Flow with 4 transformations, each parametrised by 2 layers with 64 hidden units.

# %%
def make_flow(n_parameters, device):
    K = 16
    torch.manual_seed(0)
    flows = []
    for i in range(K):
        flows.append(nf.flows.MaskedAffineAutoregressive(n_parameters, 20, num_blocks=2))
        flows.append(nf.flows.Permute(n_parameters, mode="swap"))
    q0 = nf.distributions.DiagGaussian(n_parameters)
    nfm = nf.NormalizingFlow(q0=q0, flows=flows)
    return nfm.to(device)

# %%
# Plot the inital flow:
flow = make_flow(len(true_parameters), device=device)
samples = flow.sample(10000)[0].cpu().detach().numpy()

pygtc.plotGTC([samples], truths=true_parameters.cpu().numpy(), figureSize=7, paramNames=[r"$\gamma$", r"$\rho$", r"$I_0$"]);

# %% [markdown]
# Let's also plot runs sampled from the untrained flow, to compare later with the trained flow.

# %%
f, ax = plt.subplots()

for i in range(15):
    with torch.no_grad():
        sim_sir = model(flow.sample(1)[0][0])
    ax.plot(sim_sir[1].cpu().numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[2].cpu().numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_infected.cpu(), color = "black", linewidth=2, label = "data infected")
ax.plot(true_recovered.cpu(), color = "black", linewidth=2, label = "data recovered", linestyle="--")
ax.legend()

# %% [markdown]
# ### Train the flow

# %%
torch.manual_seed(0)

class MMDLoss:
    def __init__(self, model, agent_sample):  # NOTE: agent_sample stores subset of agents' ids whose ego networks are used to compute loss
        self.model = model
        self.loss_fn = MMD()
        self.agent_sample = agent_sample
        
    def __call__(self, params, data):
        loss = simulate_and_observe_model(self.model, params, data, self.agent_sample, self.loss_fn)
        return loss

prior = torch.distributions.MultivariateNormal(-2.0 * torch.ones(3, device=device), torch.eye(3, device=device))
loss = MMDLoss(model, agent_sample=agent_sample)
optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-3)
w = 0.1

vi = VI(loss = loss,
        posterior_estimator = flow,
        prior=prior,
        optimizer=optimizer,
        w=w,
        n_samples_per_epoch=10,
        log_tensorboard=True,
        device=device,
        gradient_estimation_method='score'  # NOTE: 'score' for non-differentiable models
       )
# and we run for 1000 epochs, stopping if the loss doesn't improve in 100 epochs.

# %%
# %prun -D program.prof vi.run(data, n_epochs=10, max_epochs_without_improvement=50)
# Out:
# 100%|██████████| 10/10 [04:36<00:00, 27.63s/it, loss=22.5, reg.=1.3, total=23.8, best loss=22.2, epochs since improv.=6]
#
# *** Profile stats marshalled to file 'program.prof'.
#          454630764 function calls (449257871 primitive calls) in 276.359 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   1414000   45.404    0.000   45.404    0.000 {method 'tolist' of 'torch._C._TensorBase' objects}
#     20200   21.857    0.001  146.329    0.007 sir_agents_torch_egonets_cal.py:215(get_ego_net)
#     70700   16.373    0.000   24.692    0.000 weisfeiler_lehman.py:202(generate_graphs)
#    202000   10.577    0.000   17.981    0.000 subgraph.py:39(subgraph)
#   6302400    8.381    0.000   11.206    0.000 graph.py:899(add_edge)
#     60600    7.890    0.000   26.034    0.000 vertex_histogram.py:60(parse_input)
#    202000    5.694    0.000   69.886    0.000 convert.py:80(to_networkx)
#  42745130    5.408    0.000   11.583    0.000 {built-in method builtins.isinstance}
#    212100    5.122    0.000   11.673    0.000 utils.py:233(graph_from_networkx)
#  29694000    4.208    0.000   12.801    0.000 graph.py:1652(<genexpr>)
# 5696450/1212050    3.535    0.000   21.060    0.000 {built-in method builtins.all}
#     60500    3.505    0.000    3.505    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#  28070920    3.426    0.000    6.176    0.000 abc.py:117(__instancecheck__)
#  11211000    3.307    0.000    3.307    0.000 weisfeiler_lehman.py:222(<listcomp>)
#  11271623    2.999    0.000    2.999    0.000 {built-in method builtins.sorted}
#  11084650    2.807    0.000    3.024    0.000 {built-in method builtins.iter}
#  28070920    2.749    0.000    2.749    0.000 {built-in method _abc._abc_instancecheck}
#    463320    2.715    0.000    5.332    0.000 _sputils.py:149(get_index_dtype)
#     10100    2.498    0.000    4.472    0.000 rooted_subgraph.py:76(map)
#   2174520    2.489    0.000    3.665    0.000 {built-in method numpy.asarray}
#    202000    2.381    0.000   35.944    0.000 data.py:585(subgraph)
#   4888400    2.284    0.000   20.075    0.000 graph.py:1650(<genexpr>)
#   6706400    2.144    0.000    3.086    0.000 six.py:601(itervalues)
#    232420    2.118    0.000    2.118    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#  11007021    1.803    0.000    2.279    0.000 {built-in method builtins.getattr}
#    202000    1.694    0.000    3.156    0.000 mask.py:33(index_to_mask)
#  32462417    1.636    0.000    1.636    0.000 {method 'append' of 'list' objects}
#    202000    1.550    0.000    1.830    0.000 graph.py:566(add_nodes_from)
#   1010000    1.472    0.000    2.703    0.000 storage.py:565(is_node_attr)
#  18541027    1.450    0.000    1.450    0.000 {method 'get' of 'dict' objects}
#     10100    1.412    0.000  102.023    0.010 weisfeiler_lehman.py:112(parse_input)
#    257400    1.333    0.000    2.869    0.000 _compressed.py:135(check_format)
#    202000    1.312    0.000    9.704    0.000 function_base.py:2443(_vectorize_call)
#    404240    1.298    0.000    1.301    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
# 257400/205920    1.271    0.000   17.876    0.000 _compressed.py:27(__init__)
#   6706400    1.255    0.000    1.714    0.000 misc.py:595(_clear_cache)
#    404000    1.248    0.000   23.840    0.000 graph.py:1585(is_edge_dictionary)
#  11266700    1.225    0.000    1.225    0.000 {method 'add' of 'set' objects}
#    202000    1.185    0.000    1.185    0.000 {built-in method torch._unique2}
#    505000    1.179    0.000    2.429    0.000 {built-in method numpy.asanyarray}
#     20200    1.174    0.000    1.174    0.000 {method 'nonzero' of 'torch._C._TensorBase' objects}
#    212100    1.170    0.000    1.170    0.000 {built-in method torch.arange}
#    202000    1.163    0.000    3.047    0.000 function.py:568(set_node_attributes)
# 18708522/18661062    1.149    0.000    1.161    0.000 {built-in method builtins.len}
#    202000    1.123    0.000    1.123    0.000 sir_agents_torch_egonets_cal.py:221(<dictcomp>)
#    202000    1.045    0.000    5.877    0.000 function_base.py:2374(_get_ufunc_and_otypes)
#   4484400    1.037    0.000    1.401    0.000 reportviews.py:188(__getitem__)
#     30300    1.036    0.000    1.747    0.000 storage.py:34(__init__)
#        20    1.030    0.051    1.030    0.051 {method 'run_backward' of 'torch._C._EngineBase' objects}
#    404000    1.007    0.000    1.678    0.000 functools.py:961(__get__)
#    909101    1.003    0.000    3.301    0.000 storage.py:83(__setattr__)
#   6141608    0.972    0.000    1.410    0.000 enum.py:783(__hash__)
#    453840    0.964    0.000    0.964    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# 16615608/16615596    0.946    0.000    0.946    0.000 {method 'keys' of 'dict' objects}
#    949400    0.894    0.000    1.584    0.000 storage.py:66(_pop_cache)
#    232100    0.890    0.000    0.890    0.000 {method 'new_zeros' of 'torch._C._TensorBase' objects}
#    212100    0.889    0.000    0.889    0.000 {built-in method torch.squeeze}
#    202000    0.887    0.000    1.652    0.000 function_base.py:2285(__init__)
#    237220    0.882    0.000    0.882    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#   3334010    0.860    0.000    1.270    0.000 view.py:38(__iter__)
#    404000    0.859    0.000    0.859    0.000 {method 'squeeze' of 'torch._C._TensorBase' objects}
#   1010000    0.853    0.000    1.491    0.000 storage.py:611(is_edge_attr)
#    222210    0.835    0.000    0.835    0.000 {method 't' of 'torch._C._TensorBase' objects}
#    202000    0.820    0.000    0.820    0.000 {built-in method numpy.frompyfunc}
#  12604800    0.800    0.000    0.800    0.000 utils.py:302(edgel_put)
#   2242200    0.783    0.000    1.454    0.000 utils.py:289(nodel_put)
#    627860    0.768    0.000    0.768    0.000 {built-in method numpy.array}
#   8807225    0.763    0.000    0.763    0.000 {method 'update' of 'dict' objects}
#   1212000    0.761    0.000    0.761    0.000 {built-in method _collections._count_elements}
#    463320    0.758    0.000    6.384    0.000 _base.py:1303(_get_index_dtype)
#     10000    0.748    0.000   11.233    0.001 sir_agents_torch_egonets_cal.py:73(step)
#    204220    0.747    0.000    0.747    0.000 {built-in method torch.zeros}
#     51480    0.732    0.000    1.984    0.000 _coo.py:185(_check)
#    276285    0.731    0.000    1.519    0.000 _compressed.py:1295(prune)
#       100    0.729    0.007  273.703    2.737 sir_agents_torch_egonets_cal.py:182(simulate_and_observe_model)
#     20200    0.728    0.000    0.728    0.000 {method 'sort' of 'torch._C._TensorBase' objects}
#    926640    0.723    0.000    0.723    0.000 getlimits.py:685(__init__)
# 616100/212100    0.708    0.000    3.004    0.000 copy.py:66(copy)
#  12604800    0.664    0.000    0.664    0.000 utils.py:320(get_weight)
#   1616000    0.646    0.000    1.577    0.000 data.py:788(__iter__)
#     10100    0.641    0.000    0.641    0.000 {built-in method torch._ops.torch_sparse.spmm_sum}
#    202000    0.635    0.000   12.769    0.000 sir_agents_torch_egonets_cal.py:210(map_states)
#   1616000    0.631    0.000    1.369    0.000 data.py:794(__call__)
#    202000    0.630    0.000    0.743    0.000 graph.py:1656(<setcomp>)
#   1212000    0.624    0.000    2.550    0.000 __init__.py:565(__init__)
#    202000    0.615    0.000    0.615    0.000 function_base.py:2409(<listcomp>)
#    464700    0.609    0.000    1.749    0.000 data.py:154(num_nodes)
#    408020    0.606    0.000    0.606    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     10100    0.595    0.000  103.408    0.010 weisfeiler_lehman.py:269(fit_transform)
#     20100    0.593    0.000    5.102    0.000 functional.py:1849(gumbel_softmax)
#    202000    0.591    0.000    2.480    0.000 data.py:466(__copy__)
#   1616000    0.588    0.000    0.872    0.000 six.py:604(iteritems)
# 7696492/7696490    0.554    0.000    0.554    0.000 {method 'values' of 'dict' objects}
# 404000/202000    0.552    0.000    2.314    0.000 _jit_internal.py:474(fn)
#   2242200    0.542    0.000    2.692    0.000 graph.py:1318(neighbors)
#    404100    0.527    0.000    2.427    0.000 _tensor.py:966(__array__)
#   1212000    0.519    0.000    1.926    0.000 __init__.py:640(update)
#    494700    0.516    0.000    1.108    0.000 data.py:805(edge_index)
#   2709024    0.509    0.000    0.509    0.000 storage.py:102(__getitem__)
#    257400    0.501    0.000    1.041    0.000 _sputils.py:296(check_shape)
#     20100    0.498    0.000    6.215    0.000 sir_agents_torch_egonets_cal.py:39(sample_bernoulli_gs)
#     51480    0.498    0.000    7.384    0.000 _compressed.py:512(_matmul_sparse)
#     10100    0.490    0.000    0.686    0.000 utils.py:4(soft_maximum)
#    202000    0.489    0.000    1.129    0.000 storage.py:120(__copy__)
#     30795    0.480    0.000    0.480    0.000 {built-in method torch.tensor}
#   1061410    0.470    0.000    0.703    0.000 _collections_abc.py:828(__contains__)
#     10100    0.470    0.000    8.985    0.001 rooted_subgraph.py:114(extract)
#   6244572    0.463    0.000    0.463    0.000 {built-in method builtins.hash}
#    202000    0.458    0.000    0.668    0.000 graph.py:332(__init__)
#     30200    0.454    0.000    0.454    0.000 {built-in method torch.vstack}
#    202000    0.443    0.000   10.147    0.000 function_base.py:2337(_call_as_normal)
#     10100    0.426    0.000   10.917    0.001 sir_agents_torch_egonets_cal.py:115(observe)
#   1414000    0.422    0.000    0.591    0.000 __init__.py:505(is_tensor)
#   1010000    0.375    0.000    3.078    0.000 data.py:575(is_node_attr)
#    474700    0.362    0.000    3.136    0.000 data.py:443(__setattr__)
#    455005    0.359    0.000    0.511    0.000 storage.py:169(items)
#     20100    0.359    0.000    0.359    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#    202000    0.355    0.000   24.666    0.000 graph.py:172(build_graph)
#     51480    0.353    0.000    1.345    0.000 _coo.py:350(_coo_to_compressed)
#   1010000    0.353    0.000    1.843    0.000 data.py:580(is_edge_attr)
#    798465    0.351    0.000    0.351    0.000 {built-in method builtins.hasattr}
#    665320    0.345    0.000    0.711    0.000 {built-in method builtins.any}
#    202000    0.335    0.000   10.482    0.000 function_base.py:2367(__call__)
#    586204    0.332    0.000    0.476    0.000 storage.py:73(__getattr__)
#     51480    0.329    0.000    6.504    0.000 _coo.py:27(__init__)
#   1464960    0.322    0.000    0.322    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#   1362540    0.322    0.000    0.962    0.000 _base.py:294(nnz)
#     51480    0.321    0.000    2.966    0.000 _csc.py:44(tocsr)
#     40320    0.310    0.000    0.310    0.000 {built-in method torch.rsub}
#    515705    0.302    0.000    0.656    0.000 storage.py:286(num_nodes)
#    464700    0.297    0.000    0.899    0.000 data.py:172(<listcomp>)
#    202000    0.291    0.000    0.697    0.000 function_base.py:2433(<listcomp>)
#    455005    0.290    0.000    0.410    0.000 view.py:10(_keys)
#    617761    0.289    0.000    0.407    0.000 <frozen importlib._bootstrap>:404(parent)
#   1259580    0.281    0.000    0.281    0.000 _compressed.py:114(_getnnz)
#    404000    0.273    0.000    0.348    0.000 graph.py:694(get_labels)
#    510040    0.273    0.000    0.273    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#    204010    0.271    0.000    0.271    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#     20100    0.253    0.000    0.253    0.000 {method 'exponential_' of 'torch._C._TensorBase' objects}
#    474700    0.248    0.000    0.882    0.000 storage.py:105(__setitem__)
#     30720    0.248    0.000    0.248    0.000 {built-in method torch._C._nn.linear}
#     20000    0.246    0.000    2.027    0.000 message_passing.py:382(propagate)
#    202000    0.245    0.000    1.716    0.000 functional.py:879(_return_output)
#     10100    0.244    0.000   62.900    0.006 weisfeiler_lehman.py:250(<listcomp>)
#    202000    0.239    0.000    0.434    0.000 function_base.py:348(iterable)
#    308880    0.237    0.000    0.279    0.000 _base.py:113(__init__)
#    202000    0.234    0.000    1.439    0.000 functional.py:722(_unique_impl)
#     60600    0.231    0.000   37.404    0.001 kernel.py:170(fit_transform)
#    202000    0.230    0.000   12.469    0.000 graph.py:987(_import_dictionary)
# 112200/35560    0.226    0.000  107.445    0.003 module.py:1494(_call_impl)
#    404000    0.223    0.000    0.807    0.000 data.py:434(__getattr__)
#   2266030    0.220    0.000    0.220    0.000 {method 'items' of 'dict' objects}
#     40210    0.220    0.000    0.220    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#    772200    0.217    0.000    0.265    0.000 _sputils.py:327(<genexpr>)
#     20000    0.206    0.000    0.605    0.000 message_passing.py:317(_collect)
#     40000    0.202    0.000    0.202    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#     20100    0.202    0.000    0.202    0.000 {method 'scatter_' of 'torch._C._TensorBase' objects}
#     30320    0.199    0.000    0.199    0.000 {built-in method torch.exp}
#     10100    0.199    0.000    0.199    0.000 {built-in method torch.argmax}
#    758490    0.198    0.000    0.249    0.000 _base.py:73(_shape_as_2d)
#     10100    0.198    0.000    1.006    0.000 transpose.py:7(t)
#    102960    0.195    0.000    0.776    0.000 fromnumeric.py:3176(ndim)
#     10100    0.181    0.000    0.426    0.000 type_check.py:403(nan_to_num)
#     51480    0.181    0.000    0.181    0.000 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#     10100    0.179    0.000    0.179    0.000 {method 'new_ones' of 'torch._C._TensorBase' objects}
#    202000    0.177    0.000    0.270    0.000 graph.py:738(nodes)
#     20000    0.176    0.000    0.176    0.000 {built-in method torch.clip}
#     10100    0.174    0.000    0.174    0.000 {built-in method torch._ops.torch_sparse.ind2ptr}
#   2301589    0.172    0.000    0.172    0.000 {method 'discard' of 'set' objects}
#    202000    0.172    0.000    0.241    0.000 graph.py:1539(is_adjacency)
#     51480    0.170    0.000    0.236    0.000 _matrix.py:12(_coo_container)
#     70700    0.168    0.000    0.452    0.000 _set_output.py:227(_get_output_config)
#    552570    0.163    0.000    0.163    0.000 _util.py:225(_prune_array)
# 494901/484801    0.163    0.000    2.676    0.000 {built-in method builtins.setattr}
#    862228    0.161    0.000    0.161    0.000 {built-in method torch._C._has_torch_function_unary}
#    463320    0.160    0.000    0.160    0.000 getlimits.py:696(min)
#    808000    0.159    0.000    0.159    0.000 graph.py:1611(<genexpr>)
#    494700    0.157    0.000    0.220    0.000 data.py:456(__getitem__)
#     20000    0.156    0.000    0.156    0.000 {method 'scatter_add_' of 'torch._C._TensorBase' objects}
#     51480    0.156    0.000    0.411    0.000 _compressed.py:1178(toarray)
#     40690    0.156    0.000    0.520    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#     51480    0.154    0.000    0.154    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat}
#    183153    0.154    0.000    0.154    0.000 threading.py:1145(ident)
#     60600    0.153    0.000   26.268    0.000 kernel.py:92(fit)
#    404000    0.153    0.000    0.153    0.000 function_base.py:2405(<genexpr>)
#    360360    0.153    0.000    0.153    0.000 {built-in method numpy.empty}
#    455005    0.152    0.000    0.152    0.000 view.py:6(__init__)
#     51005    0.150    0.000    0.327    0.000 storage.py:405(num_edges)
#     51480    0.149    0.000    0.149    0.000 {built-in method scipy.sparse._sparsetools.csc_tocsr}
#     10100    0.147    0.000    0.833    0.000 utils.py:17(soft_minimum)
#    202000    0.143    0.000   24.809    0.000 graph.py:152(__init__)
#    154430    0.141    0.000    0.141    0.000 {built-in method torch._C._get_tracing_state}
#     10100    0.140    0.000    0.140    0.000 {built-in method torch.eye}
#     40210    0.140    0.000    0.140    0.000 {method 'log' of 'torch._C._TensorBase' objects}
#    796003    0.139    0.000    0.139    0.000 {built-in method builtins.issubclass}
#     51480    0.138    0.000    0.138    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_maxnnz}
#    464722    0.136    0.000    0.137    0.000 {built-in method builtins.sum}
#     51480    0.135    0.000    7.660    0.000 _base.py:544(_matmul_dispatch)
#     20260    0.134    0.000    0.134    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#    257400    0.134    0.000    1.078    0.000 _sputils.py:240(isshape)
#    154470    0.134    0.000    0.276    0.000 numeric.py:1855(isscalar)
# 70700/10100    0.133    0.000  103.496    0.010 _set_output.py:311(wrapped)
#    202000    0.132    0.000    2.162    0.000 function_base.py:2404(<listcomp>)
#    102960    0.131    0.000    0.359    0.000 _coo.py:161(_getnnz)
#    102960    0.130    0.000    0.923    0.000 _sputils.py:218(isintlike)
#    202000    0.130    0.000    0.153    0.000 reportviews.py:1058(__init__)
#     60600    0.128    0.000   10.686    0.000 vertex_histogram.py:149(_calculate_kernel_matrix)
#     10100    0.127    0.000    0.145    0.000 numeric.py:841(outer)
#    808000    0.127    0.000    0.165    0.000 graph.py:1631(<genexpr>)
#     60600    0.127    0.000    0.127    0.000 {built-in method numpy.zeros}
#    308880    0.122    0.000    0.401    0.000 _data.py:21(__init__)
#     30720    0.121    0.000    0.394    0.000 made.py:80(forward)
#    192200    0.120    0.000    0.120    0.000 module.py:1601(__getattr__)
#    202000    0.120    0.000    0.762    0.000 utils.py:338(take_ne)
#     22088    0.119    0.000    0.119    0.000 {built-in method torch.zeros_like}
#    463320    0.119    0.000    0.119    0.000 getlimits.py:709(max)
#    617761    0.118    0.000    0.118    0.000 {method 'rpartition' of 'str' objects}
#    282800    0.118    0.000    0.118    0.000 {method 'copy' of 'dict' objects}
#     60000    0.117    0.000    0.136    0.000 inspector.py:52(distribute)
#     10100    0.111    0.000    0.525    0.000 storage.py:407(csr2csc)
#     30300    0.108    0.000    0.293    0.000 _methods.py:101(_mean)
#     10100    0.108    0.000  104.299    0.010 loss.py:13(forward)
#    415582    0.107    0.000    0.107    0.000 {built-in method __new__ of type object at 0x744500}
#     20345    0.106    0.000    0.260    0.000 ipkernel.py:790(<setcomp>)
#     70700    0.106    0.000    0.235    0.000 fromnumeric.py:1565(diagonal)
#     40000    0.106    0.000    0.332    0.000 message_passing.py:249(_lift)
#    464700    0.105    0.000    0.105    0.000 data.py:501(node_stores)
#     51480    0.105    0.000    0.237    0.000 _compressed.py:1210(has_canonical_format)
#   1132576    0.105    0.000    0.105    0.000 multiarray.py:503(can_cast)
#      9120    0.104    0.000    0.104    0.000 {method 'dot' of 'numpy.ndarray' objects}
#    202000    0.104    0.000    1.862    0.000 function_base.py:2453(<listcomp>)
#    202000    0.101    0.000    0.101    0.000 graph.py:59(__set__)
#    102960    0.101    0.000    0.246    0.000 numerictypes.py:357(issubdtype)
#     51480    0.099    0.000    1.949    0.000 _csr.py:55(transpose)
#     40210    0.099    0.000    0.407    0.000 _tensor.py:920(__iter__)
#     70700    0.097    0.000    0.097    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#    202000    0.095    0.000    0.248    0.000 graph.py:1361(edges)
#    772200    0.095    0.000    0.095    0.000 _sputils.py:336(<genexpr>)
#     70700    0.094    0.000    0.094    0.000 kernel.py:356(initialize)
#     51480    0.094    0.000    0.133    0.000 _matrix.py:17(_csc_container)
#    202000    0.093    0.000    0.093    0.000 reportviews.py:178(__init__)
#    360382    0.092    0.000    0.092    0.000 {built-in method builtins.max}
#     10100    0.092    0.000    0.092    0.000 {method 'any' of 'torch._C._TensorBase' objects}
#    205920    0.091    0.000    0.615    0.000 {method 'max' of 'numpy.ndarray' objects}
#     20000    0.089    0.000    0.089    0.000 {method 'expand_as' of 'torch._C._TensorBase' objects}
#     10110    0.088    0.000    0.088    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#     70700    0.087    0.000    0.087    0.000 _set_output.py:187(supported_outputs)
#     20345    0.087    0.000    0.095    0.000 threading.py:1478(enumerate)
#    205920    0.087    0.000    0.139    0.000 numerictypes.py:283(issubclass_)
#     10100    0.086    0.000   10.026    0.001 rooted_subgraph.py:95(__call__)
#     10100    0.085    0.000    0.085    0.000 ufunclike.py:71(isposinf)
#    617760    0.085    0.000    0.085    0.000 _matrix.py:64(get_shape)
#     10240    0.085    0.000    0.556    0.000 made.py:201(forward)
#     51480    0.085    0.000    0.115    0.000 _matrix.py:22(_csr_container)
#     51480    0.085    0.000    0.679    0.000 _compressed.py:1239(sum_duplicates)
#     10100    0.082    0.000    1.665    0.000 tensor.py:59(from_edge_index)
#     23338    0.080    0.000    0.080    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#     20100    0.080    0.000    0.080    0.000 {built-in method torch.empty_like}
#     51480    0.080    0.000    8.067    0.000 _base.py:434(dot)
#    424371    0.079    0.000    0.079    0.000 {method '__exit__' of '_thread.RLock' objects}
#     30300    0.077    0.000    0.090    0.000 _methods.py:67(_count_reduce_items)
#    100000    0.077    0.000    0.084    0.000 sparse.py:56(is_torch_sparse_tensor)
#     18885    0.075    0.000    0.075    0.000 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#     20480    0.075    0.000    0.075    0.000 {built-in method torch.relu}
#      4800    0.075    0.000    0.155    0.000 autoregressive.py:108(_elementwise_inverse)
#     15220    0.075    0.000    0.075    0.000 {built-in method torch.log}
# 60530/50430    0.075    0.000    0.671    0.000 _tensor.py:34(wrapped)
#    202000    0.074    0.000    0.074    0.000 graph.py:37(__set__)
#    404000    0.074    0.000    0.074    0.000 graph.py:282(desired_format)
#     51480    0.074    0.000    0.074    0.000 _sputils.py:111(getdtype)
#    205920    0.073    0.000    0.344    0.000 {method 'min' of 'numpy.ndarray' objects}
#     51480    0.071    0.000    3.071    0.000 _base.py:381(asformat)
#    257400    0.071    0.000    0.090    0.000 _base.py:69(ndim)
#     20000    0.071    0.000    0.544    0.000 scatter.py:23(scatter)
#     60600    0.070    0.000    0.109    0.000 vertex_histogram.py:43(__init__)
#    102960    0.070    0.000    0.127    0.000 _sputils.py:24(upcast)
#     10100    0.070    0.000    0.114    0.000 type_check.py:393(_getmaxmin)
#     20000    0.070    0.000    0.786    0.000 message_passing.py:595(aggregate)
#     20000    0.070    0.000    2.097    0.000 sir_agents_torch_egonets_cal.py:161(forward)
#    308880    0.070    0.000    0.070    0.000 _base.py:314(format)
#     10100    0.069    0.000    0.496    0.000 data.py:407(__init__)
#    308880    0.069    0.000    0.096    0.000 _base.py:1335(issparse)
#     20200    0.068    0.000    1.643    0.000 tensor.py:16(__init__)
#     20000    0.068    0.000    0.140    0.000 message_passing.py:202(_check_input)
#     20000    0.067    0.000    0.067    0.000 sir_agents_torch_egonets_cal.py:178(message)
#    102960    0.067    0.000    0.227    0.000 _sputils.py:213(isscalarlike)
#     51480    0.066    0.000    0.066    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#    202000    0.065    0.000    0.065    0.000 num_nodes.py:23(maybe_num_nodes)
#    205920    0.065    0.000    0.524    0.000 _methods.py:39(_amax)
#     51480    0.064    0.000    0.064    0.000 {built-in method scipy.sparse._sparsetools.csr_todense}
#    707010    0.063    0.000    0.063    0.000 _csr.py:160(_swap)
#    308880    0.063    0.000    0.076    0.000 _coo.py:164(<genexpr>)
#     20200    0.062    0.000    0.136    0.000 _ufunc_config.py:33(seterr)
#     10100    0.059    0.000    0.251    0.000 storage.py:202(rowptr)
#    154440    0.058    0.000    0.485    0.000 _coo.py:59(<genexpr>)
#     70700    0.056    0.000    0.184    0.000 _config.py:32(get_config)
#    202000    0.055    0.000    0.075    0.000 reportviews.py:185(__iter__)
#     70700    0.054    0.000    0.507    0.000 _set_output.py:262(_wrap_data_with_container)
#    257400    0.054    0.000    0.054    0.000 _data.py:24(dtype)
#     40320    0.053    0.000    0.363    0.000 _tensor.py:846(__rsub__)
#        10    0.053    0.005  275.355   27.535 vi.py:275(compute_and_differentiate_loss)
#     10100    0.051    0.000    0.160    0.000 weisfeiler_lehman.py:243(<dictcomp>)
#    205920    0.051    0.000    0.271    0.000 _methods.py:43(_amin)
#    538480    0.051    0.000    0.051    0.000 {built-in method _operator.index}
#     20000    0.050    0.000    0.694    0.000 base.py:86(__call__)
#    202000    0.050    0.000    0.070    0.000 _base.py:1364(isspmatrix)
#    202000    0.050    0.000    0.050    0.000 graph.py:1179(get_edge_dictionary)
#     51480    0.050    0.000    0.159    0.000 _base.py:1290(_process_toarray_args)
#     10100    0.048    0.000    0.048    0.000 {built-in method torch.result_type}
#     51480    0.048    0.000    0.367    0.000 _sputils.py:137(getdata)
#    102010    0.047    0.000    0.058    0.000 data.py:520(__cat_dim__)
#     51480    0.047    0.000    7.835    0.000 _base.py:665(__matmul__)
#     10100    0.046    0.000    0.130    0.000 storage.py:54(__init__)
#     10100    0.046    0.000    0.966    0.000 matmul.py:9(spmm_sum)
#    105961    0.044    0.000    0.075    0.000 serialization.py:602(persistent_id)
#     20200    0.044    0.000    0.046    0.000 _ufunc_config.py:132(geterr)
#    308880    0.042    0.000    0.042    0.000 _coo.py:168(<genexpr>)
#    202000    0.042    0.000    0.042    0.000 {built-in method builtins.callable}
#     20000    0.042    0.000    0.219    0.000 scatter.py:18(broadcast)
#     70365    0.042    0.000    0.052    0.000 _compressed.py:1233(has_canonical_format)
#    154440    0.041    0.000    0.059    0.000 _coo.py:198(<genexpr>)
#     11700    0.040    0.000    0.275    0.000 fromnumeric.py:71(_wrapreduction)
#     10100    0.039    0.000    0.233    0.000 _tensor.py:875(__rpow__)
#    202011    0.036    0.000    0.036    0.000 {method 'join' of 'str' objects}
#     70700    0.036    0.000    0.094    0.000 _config.py:24(_get_threadlocal_config)
#    121845    0.035    0.000    0.035    0.000 _compressed.py:1270(has_sorted_indices)
#     10100    0.035    0.000    0.048    0.000 weisfeiler_lehman.py:71(initialize)
#    202000    0.033    0.000    0.033    0.000 utils.py:286(nodel_init)
#    202000    0.032    0.000    0.032    0.000 reportviews.py:205(__call__)
#      5240    0.032    0.000    0.032    0.000 {built-in method torch.sum}
#     18885    0.031    0.000    0.149    0.000 _compressed.py:1286(sort_indices)
#     10100    0.031    0.000    0.031    0.000 rooted_subgraph.py:110(__init__)
#     20200    0.031    0.000    0.758    0.000 utils.py:14(index_sort)
#     10100    0.030    0.000    0.527    0.000 data.py:756(from_dict)
#     20000    0.029    0.000    0.574    0.000 base.py:146(reduce)
#     60600    0.029    0.000    0.029    0.000 kernel.py:82(__init__)
#    102960    0.029    0.000    0.037    0.000 _sputils.py:269(isdense)
#     20200    0.028    0.000    0.028    0.000 graph_store.py:110(__init__)
#     40000    0.028    0.000    0.041    0.000 message_passing.py:240(_set_size)
#    202000    0.028    0.000    0.028    0.000 utils.py:296(edgel_init)
#    151520    0.028    0.000    0.028    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#     20220    0.028    0.000    0.845    0.000 _ops.py:497(__call__)
#        13    0.028    0.002    0.186    0.014 serialization.py:592(_save)
#     18885    0.027    0.000    0.027    0.000 {built-in method scipy.sparse._sparsetools.csr_sum_duplicates}
#     10100    0.027    0.000    0.285    0.000 fromnumeric.py:2177(sum)
#     51480    0.027    0.000    1.976    0.000 _base.py:319(T)
#      5120    0.026    0.000    0.039    0.000 autoregressive.py:118(_unconstrained_scale_and_shift)
#     51480    0.025    0.000    0.025    0.000 _sputils.py:95(to_native)
#     10100    0.024    0.000    0.085    0.000 tensor.py:41(from_storage)
#      5120    0.024    0.000    0.769    0.000 made.py:296(forward)
#        10    0.024    0.002    0.071    0.007 adamw.py:342(_single_tensor_adamw)
#      4632    0.023    0.000    0.053    0.000 _tensor.py:243(_reduce_ex_internal)
#        13    0.023    0.002    0.158    0.012 {method 'dump' of '_pickle.Pickler' objects}
#     30300    0.022    0.000    0.315    0.000 {method 'mean' of 'numpy.ndarray' objects}
#      1600    0.022    0.000    0.746    0.000 autoregressive.py:29(inverse)
#    102960    0.022    0.000    0.022    0.000 _csc.py:142(_swap)
#     40000    0.021    0.000    0.076    0.000 sparse.py:73(is_sparse)
#      5820    0.021    0.000    0.021    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#     10240    0.021    0.000    0.035    0.000 functional.py:1235(dropout)
#       320    0.021    0.000    0.053    0.000 autoregressive.py:98(_elementwise_forward)
#     20000    0.020    0.000    0.594    0.000 basic.py:18(forward)
#     20200    0.019    0.000    0.019    0.000 {built-in method numpy.seterrobj}
#     10100    0.019    0.000    0.050    0.000 storage.py:191(to_dict)
#     18885    0.019    0.000    0.034    0.000 _compressed.py:1254(has_sorted_indices)
#     70700    0.019    0.000    0.019    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#     10100    0.019    0.000    0.025    0.000 tensor.py:233(coo)
#     10101    0.019    0.000    0.025    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#       100    0.018    0.000    0.816    0.008 core.py:182(log_prob)
#     10100    0.018    0.000    1.000    0.000 matmul.py:141(matmul)
#     10100    0.018    0.000    0.018    0.000 ufunclike.py:142(isneginf)
#      5120    0.018    0.000    0.018    0.000 {built-in method torch.sigmoid}
#    102960    0.017    0.000    0.017    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#     10100    0.017    0.000    0.040    0.000 feature_store.py:260(__init__)
#      1920    0.017    0.000    0.017    0.000 {built-in method torch.cat}
#      1600    0.017    0.000    0.033    0.000 mixing.py:44(inverse)
#     23680    0.017    0.000    0.038    0.000 container.py:281(_get_abs_string_index)
#     20200    0.016    0.000    0.016    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     60530    0.016    0.000    0.016    0.000 {built-in method torch._C._has_torch_function}
#    126830    0.015    0.000    0.015    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     10100    0.015    0.000    0.268    0.000 tensor.py:236(csr)
#     23680    0.014    0.000    0.055    0.000 container.py:290(__getitem__)
#     10100    0.013    0.000    0.019    0.000 getlimits.py:484(__new__)
#     10100    0.013    0.000    0.979    0.000 matmul.py:79(spmm)
#     70700    0.013    0.000    0.013    0.000 fromnumeric.py:1561(_diagonal_dispatcher)
#     10100    0.013    0.000    1.019    0.000 transpose.py:34(<lambda>)
#     60600    0.013    0.000    0.013    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#     40400    0.012    0.000    0.012    0.000 storage.py:186(row)
#       232    0.012    0.000    0.012    0.000 {method 'acquire' of '_thread.lock' objects}
#     18885    0.012    0.000    0.012    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#     10099    0.012    0.000    0.012    0.000 {built-in method builtins.delattr}
#     10100    0.012    0.000    0.061    0.000 data.py:509(to_dict)
#     11700    0.011    0.000    0.011    0.000 fromnumeric.py:72(<dictcomp>)
#     40400    0.011    0.000    0.011    0.000 {built-in method numpy.geterrobj}
#    102960    0.011    0.000    0.011    0.000 multiarray.py:85(empty_like)
#        20    0.011    0.001    0.011    0.001 {built-in method torch.randn}
#     67975    0.011    0.000    0.011    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     10100    0.010    0.000    1.010    0.000 matmul.py:171(<lambda>)
#     20480    0.010    0.000    0.087    0.000 functional.py:1446(relu)
#      3880    0.010    0.000    0.010    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#      5120    0.009    0.000    0.040    0.000 nn.py:190(sum_except_batch)
#     40000    0.008    0.000    0.008    0.000 message_passing.py:552(explain)
#     51480    0.008    0.000    0.008    0.000 _csr.py:88(tocsr)
#     47460    0.008    0.000    0.011    0.000 container.py:311(__len__)
#    101329    0.008    0.000    0.008    0.000 __init__.py:525(is_storage)
#     11580    0.008    0.000    0.010    0.000 storage.py:404(__init__)
#         1    0.007    0.007  276.355  276.355 vi.py:468(run)
#    7944/3    0.007    0.000    0.041    0.014 copy.py:128(deepcopy)
#      1158    0.006    0.000    0.032    0.000 _tensor.py:82(__deepcopy__)
# 19120/2760    0.006    0.000    0.007    0.000 module.py:2224(named_modules)
#     10240    0.006    0.000    0.006    0.000 {built-in method torch.dropout}
#        20    0.006    0.000    0.333    0.017 core.py:167(sample)
#        10    0.006    0.001  275.302   27.530 vi.py:199(compute_and_differentiate_loss_score)
#       320    0.006    0.000    0.018    0.000 mixing.py:32(forward)
#      5790    0.006    0.000    0.016    0.000 _tensor.py:237(_typed_storage)
#     11580    0.005    0.000    0.007    0.000 storage.py:332(__new__)
#        10    0.005    0.001    0.005    0.001 {built-in method torch._foreach_mul_}
#      1940    0.005    0.000    0.005    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#     10240    0.005    0.000    0.040    0.000 dropout.py:58(forward)
#     30300    0.005    0.000    0.005    0.000 multiarray.py:1080(copyto)
#     20200    0.004    0.000    0.004    0.000 storage.py:215(col)
#        10    0.004    0.000    0.007    0.001 adamw.py:85(_init_group)
#       100    0.004    0.000    0.008    0.000 base.py:94(log_prob)
#     10100    0.004    0.000    0.004    0.000 type_check.py:399(_nan_to_num_dispatcher)
#        10    0.004    0.000    0.006    0.001 optimizer.py:435(zero_grad)
#        20    0.004    0.000    0.017    0.001 base.py:80(forward)
#     10240    0.004    0.000    0.005    0.000 _VF.py:26(__getattr__)
#        10    0.004    0.000    0.004    0.000 {built-in method torch._foreach_norm}
#     20200    0.004    0.000    0.004    0.000 ufunclike.py:14(_dispatcher)
#         1    0.004    0.004  276.359  276.359 <string>:1(<module>)
#        13    0.004    0.000    0.004    0.000 serialization.py:287(__init__)
#      5140    0.003    0.000    0.005    0.000 container.py:315(__iter__)
#        13    0.003    0.000    0.003    0.000 serialization.py:290(__exit__)
#        10    0.003    0.000    0.003    0.000 {built-in method torch._C._linalg.linalg_solve_triangular}
#      2020    0.003    0.000    0.005    0.000 _tensor.py:904(__len__)
#      1940    0.003    0.000    0.003    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#      1940    0.003    0.000    0.003    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#     20000    0.003    0.000    0.003    0.000 message_passing.py:625(update)
#     10100    0.003    0.000    0.003    0.000 numeric.py:837(_outer_dispatcher)
#      4632    0.003    0.000    0.003    0.000 serialization.py:137(_cpu_tag)
#      4632    0.003    0.000    0.060    0.000 _tensor.py:208(__reduce_ex__)
#     20200    0.003    0.000    0.003    0.000 storage.py:221(value)
#        13    0.003    0.000    0.196    0.015 serialization.py:388(save)
#      1158    0.003    0.000    0.003    0.000 {method 'copy_' of 'torch._C.StorageBase' objects}
#      1950    0.003    0.000    0.012    0.000 module.py:2045(_named_members)
#      1158    0.002    0.000    0.003    0.000 {method 'set_' of 'torch._C._TensorBase' objects}
#       100    0.002    0.000    0.072    0.001 sir_agents_torch_egonets_cal.py:52(initialize)
#      4632    0.002    0.000    0.004    0.000 _utils.py:151(get_tensor_metadata)
#      4632    0.002    0.000    0.007    0.000 storage.py:729(_size)
#      4632    0.002    0.000    0.003    0.000 _utils.py:751(_element_size)
#      4632    0.002    0.000    0.005    0.000 _utils.py:372(_get_obj_state)
#     10100    0.002    0.000    0.002    0.000 fromnumeric.py:2172(_sum_dispatcher)
#      1600    0.002    0.000    0.020    0.000 fromnumeric.py:2979(prod)
#      1158    0.002    0.000    0.005    0.000 storage.py:110(clone)
#        10    0.002    0.000  276.080   27.608 vi.py:397(step)
#     825/3    0.002    0.000    0.005    0.002 module.py:1748(state_dict)
#        71    0.002    0.000    0.002    0.000 socket.py:626(send)
#        10    0.002    0.000    0.015    0.001 clip_grad.py:39(<listcomp>)
#       825    0.002    0.000    0.003    0.000 module.py:1708(_save_to_state_dict)
#      4632    0.002    0.000    0.005    0.000 serialization.py:206(location_tag)
#       100    0.002    0.000  273.704    2.737 1734702063.py:9(__call__)
#      4632    0.002    0.000    0.002    0.000 copyreg.py:109(_slotnames)
#       320    0.002    0.000    0.289    0.001 autoregressive.py:24(forward)
#      4632    0.001    0.000    0.004    0.000 storage.py:625(_element_size)
#      1940    0.001    0.000    0.003    0.000 optimizer.py:39(_get_value)
#      4308    0.001    0.000    0.002    0.000 copy.py:243(_keep_alive)
#     18528    0.001    0.000    0.001    0.000 {method 'data_ptr' of 'torch._C.StorageBase' objects}
#       120    0.001    0.000    0.001    0.000 {built-in method torch.pow}
#        20    0.001    0.000    0.001    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
# 1986/1161    0.001    0.000    0.005    0.000 copy.py:227(_deepcopy_dict)
#     22580    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      5790    0.001    0.000    0.001    0.000 {built-in method torch._C._has_storage}
#     10100    0.001    0.000    0.001    0.000 storage.py:266(sparse_sizes)
#        10    0.001    0.000    0.002    0.000 _foreach_utils.py:20(_group_tensors_by_device_and_dtype)
#        10    0.001    0.000    0.008    0.001 multivariate_normal.py:212(log_prob)
#      1940    0.001    0.000    0.002    0.000 optimizer.py:52(_dispatch_sqrt)
#     10422    0.001    0.000    0.001    0.000 {method 'nbytes' of 'torch._C.StorageBase' objects}
#      4632    0.001    0.000    0.002    0.000 _namedtensor_internals.py:10(check_serializing_named_tensor)
#      2356    0.001    0.000    0.002    0.000 grad_mode.py:149(__init__)
#      4632    0.001    0.000    0.001    0.000 {built-in method torch._C._get_tensor_metadata}
#      5790    0.001    0.000    0.001    0.000 {method 'stride' of 'torch._C._TensorBase' objects}
#       100    0.001    0.000    0.001    0.000 {built-in method torch.ones}
#       6/3    0.001    0.000    0.041    0.014 copy.py:259(_reconstruct)
#        10    0.001    0.000    0.001    0.000 {built-in method torch.stack}
#        22    0.001    0.000    0.002    0.000 std.py:464(format_meter)
#      5120    0.001    0.000    0.001    0.000 {method 'ndimension' of 'torch._C._TensorBase' objects}
#      1158    0.001    0.000    0.001    0.000 {method 'new_empty' of 'torch._C._TensorBase' objects}
#      4632    0.001    0.000    0.001    0.000 {method 'has_names' of 'torch._C._TensorBase' objects}
#      5790    0.001    0.000    0.001    0.000 {method 'untyped_storage' of 'torch._C._TensorBase' objects}
#      4632    0.001    0.000    0.001    0.000 storage.py:739(_pickle_storage_type)
#      1158    0.001    0.000    0.006    0.000 storage.py:94(__deepcopy__)
#      1158    0.001    0.000    0.002    0.000 storage.py:482(_new_wrapped_storage)
#        10    0.001    0.000    0.032    0.003 clip_grad.py:12(clip_grad_norm_)
#      6014    0.001    0.000    0.001    0.000 _tensor.py:942(__hash__)
#      4632    0.001    0.000    0.001    0.000 {method 'data_ptr' of 'torch._C._TensorBase' objects}
#      2750    0.001    0.000    0.001    0.000 module.py:2113(<lambda>)
#      4632    0.001    0.000    0.001    0.000 hooks.py:82(warn_if_has_hooks)
#      5790    0.001    0.000    0.001    0.000 {method 'setdefault' of 'dict' objects}
#      1168    0.001    0.000    0.001    0.000 grad_mode.py:48(__init__)
#      5790    0.001    0.000    0.001    0.000 {method 'storage_offset' of 'torch._C._TensorBase' objects}
#        20    0.001    0.000    0.001    0.000 {method 'all' of 'torch._C._TensorBase' objects}
#      1168    0.001    0.000    0.002    0.000 grad_mode.py:53(__enter__)
#      5120    0.001    0.000    0.001    0.000 linear.py:44(forward)
#      1158    0.001    0.000    0.012    0.000 storage.py:660(_deepcopy)
#      4632    0.001    0.000    0.001    0.000 {method 'get' of 'mappingproxy' objects}
#      1940    0.001    0.000    0.001    0.000 {built-in method torch.is_complex}
#        20    0.001    0.000    0.001    0.000 {built-in method torch._ops.profiler.}
#      5120    0.001    0.000    0.001    0.000 autoregressive.py:95(_output_dim_multiplier)
#      1950    0.001    0.000    0.013    0.000 module.py:2059(parameters)
#      1950    0.001    0.000    0.001    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#      1950    0.000    0.000    0.012    0.000 module.py:2084(named_parameters)
#        10    0.000    0.000    0.000    0.000 constraints.py:307(check)
#        30    0.000    0.000    0.002    0.000 summary.py:264(scalar)
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#      1168    0.000    0.000    0.001    0.000 grad_mode.py:57(__exit__)
#        20    0.000    0.000    0.000    0.000 _foreach_utils.py:42(<listcomp>)
#      5098    0.000    0.000    0.000    0.000 _jit_internal.py:1102(is_scripting)
#       140    0.000    0.000    0.000    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000    0.002    0.000 clip_grad.py:46(<listcomp>)
#       100    0.000    0.000    0.001    0.000 _tensor.py:976(__array_wrap__)
#        10    0.000    0.000    0.005    0.001 multivariate_normal.py:25(_batch_mahalanobis)
#        40    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#      2557    0.000    0.000    0.001    0.000 utils.py:375(<genexpr>)
#      3534    0.000    0.000    0.000    0.000 {built-in method torch.is_grad_enabled}
#        20    0.000    0.000    1.030    0.052 __init__.py:106(backward)
#      1950    0.000    0.000    0.000    0.000 adamw.py:293(<genexpr>)
#        20    0.000    0.000    0.001    0.000 _foreach_utils.py:39(_has_foreach_support)
#        10    0.000    0.000    0.303    0.030 vi.py:18(compute_regularisation_loss)
#        10    0.000    0.000    0.000    0.000 {method 'mean' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.mkdir}
#        10    0.000    0.000    0.081    0.008 optimizer.py:265(wrapper)
#      1600    0.000    0.000    0.000    0.000 fromnumeric.py:2974(_prod_dispatcher)
#        24    0.000    0.000    0.002    0.000 iostream.py:655(write)
#        10    0.000    0.000    0.002    0.000 distribution.py:262(_validate_sample)
#        10    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_isCurrentStreamCapturing}
#        10    0.000    0.000    0.080    0.008 optimizer.py:29(_use_grad)
#        10    0.000    0.000    0.001    0.000 clip_grad.py:61(<listcomp>)
#        20    0.000    0.000    0.001    0.000 profiler.py:495(__exit__)
#      3636    0.000    0.000    0.000    0.000 copy.py:182(_deepcopy_atomic)
#        30    0.000    0.000    0.003    0.000 writer.py:348(add_scalar)
#        20    0.000    0.000    1.031    0.052 _tensor.py:428(backward)
#      1940    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#      2356    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#        30    0.000    0.000    0.000    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#      78/5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#      1158    0.000    0.000    0.000    0.000 {method 'is_neg' of 'torch._C._TensorBase' objects}
#      1158    0.000    0.000    0.000    0.000 {method 'is_conj' of 'torch._C._TensorBase' objects}
#        71    0.000    0.000    0.002    0.000 iostream.py:259(schedule)
#        10    0.000    0.000    0.010    0.001 std.py:1402(set_postfix)
#      2535    0.000    0.000    0.000    0.000 {built-in method unicodedata.east_asian_width}
#       100    0.000    0.000    0.000    0.000 {built-in method torch.from_numpy}
#        20    0.000    0.000    0.000    0.000 {built-in method torch.ones_like}
#         1    0.000    0.000    0.003    0.003 writer.py:178(__init__)
#        50    0.000    0.000    0.000    0.000 std.py:419(format_num)
#        20    0.000    0.000    0.002    0.000 profiler.py:491(__enter__)
#        24    0.000    0.000    0.012    0.001 iostream.py:592(flush)
#        20    0.000    0.000    0.000    0.000 profiler.py:482(__init__)
#      1940    0.000    0.000    0.000    0.000 _utils.py:786(is_compiling)
#        32    0.000    0.000    0.001    0.000 queue.py:122(put)
#       100    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 __init__.py:50(_make_grads)
#        22    0.000    0.000    0.000    0.000 std.py:1446(format_dict)
#        10    0.000    0.000    0.079    0.008 adamw.py:135(step)
#        10    0.000    0.000    0.000    0.000 _tensor.py:850(__rdiv__)
#        30    0.000    0.000    0.000    0.000 threading.py:236(__init__)
#        30    0.000    0.000    0.001    0.000 writer.py:84(add_event)
#        10    0.000    0.000    0.000    0.000 functional.py:1387(norm)
#        31    0.000    0.000    0.001    0.000 event_file_writer.py:165(write)
#        26    0.000    0.000    0.012    0.000 threading.py:288(wait)
#        10    0.000    0.000    0.001    0.000 constraints.py:208(check)
#        10    0.000    0.000    0.000    0.000 {built-in method torch._C._linalg.linalg_vector_norm}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.clamp}
#        44    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#        30    0.000    0.000    0.001    0.000 _convert_np.py:31(_prepare_pytorch)
#        55    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      1158    0.000    0.000    0.000    0.000 storage.py:24(__init__)
#        44    0.000    0.000    0.000    0.000 utils.py:273(_is_ascii)
#        10    0.000    0.000    0.000    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000    0.000    0.000 {method 'diagonal' of 'torch._C._TensorBase' objects}
#        30    0.000    0.000    0.001    0.000 _convert_np.py:8(make_np)
#        95    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#        30    0.000    0.000    0.001    0.000 writer.py:100(add_summary)
#        22    0.000    0.000    0.002    0.000 std.py:1150(__str__)
#        42    0.000    0.000    0.000    0.000 std.py:400(format_interval)
#        22    0.000    0.000    0.016    0.001 std.py:1464(display)
#        79    0.000    0.000    0.000    0.000 std.py:231(__call__)
#        21    0.000    0.000    0.016    0.001 std.py:1325(refresh)
#        10    0.000    0.000    0.006    0.001 std.py:1198(update)
#        25    0.000    0.000    0.000    0.000 std.py:106(release)
#        46    0.000    0.000    0.013    0.000 utils.py:194(inner)
#         1    0.000    0.000    0.000    0.000 synchronize.py:50(__init__)
#        11    0.000    0.000    0.000    0.000 os.py:675(__getitem__)
#        26    0.000    0.000    0.011    0.000 threading.py:589(wait)
#        10    0.000    0.000    0.039    0.004 vi.py:61(_sample_and_scatter_parameters)
#        31    0.000    0.000    0.001    0.000 event_file_writer.py:106(add_event)
#        32    0.000    0.000    0.000    0.000 threading.py:359(notify)
#        10    0.000    0.000    0.000    0.000 __init__.py:91(_nvml_based_avail)
#        22    0.000    0.000    0.014    0.001 std.py:457(print_status)
#        27    0.000    0.000    0.000    0.000 threading.py:545(__init__)
#        10    0.000    0.000    0.001    0.000 optimizer.py:228(_cuda_graph_capture_health_check)
#        22    0.000    0.000    0.013    0.001 std.py:451(fp_write)
#        22    0.000    0.000    0.000    0.000 std.py:186(__format__)
#        25    0.000    0.000    0.000    0.000 std.py:102(acquire)
#        21    0.000    0.000    0.000    0.000 {built-in method now}
# ...
#        31    0.000    0.000    0.002    0.000 writer.py:274(_get_file_writer)
#        10    0.000    0.000    0.000    0.000 _collections_abc.py:821(get)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        13    0.000    0.000    0.000    0.000 serialization.py:361(_check_dill_version)
#        22    0.000    0.000    0.001    0.000 utils.py:374(_text_width)
#         2    0.000    0.000    0.000    0.000 threading.py:827(__init__)
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x7f2da5cfe4d0}
#        13    0.000    0.000    0.000    0.000 serialization.py:235(_is_path)
#        11    0.000    0.000    0.000    0.000 os.py:755(encode)
#        27    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        84    0.000    0.000    0.000    0.000 {built-in method time.time}
#        32    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#       100    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       129    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 __init__.py:98(_tensor_or_tensors_to_tuple)
#        31    0.000    0.000    0.000    0.000 {method 'SerializeToString' of 'google._upb._message.Message' objects}
#        25    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#        13    0.000    0.000    0.000    0.000 serialization.py:240(__init__)
#         1    0.000    0.000    0.000    0.000 _ops.py:239(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        22    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#        55    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.001    0.001 std.py:663(__new__)
#        97    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 _foreach_utils.py:27(<lambda>)
#       106    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#        30    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:333(_screen_shape_linux)
#       100    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1028(_stop)
#        25    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#        10    0.000    0.000    0.000    0.000 _foreach_utils.py:24(<listcomp>)
#         3    0.000    0.000    0.001    0.000 event_file_writer.py:180(flush)
#         1    0.000    0.000    0.000    0.000 _ops.py:447(__getattr__)
#        22    0.000    0.000    0.000    0.000 std.py:167(colour)
#         2    0.000    0.000    0.001    0.001 threading.py:916(start)
#        61    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        26    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#        10    0.000    0.000    0.000    0.000 __init__.py:87(_is_compiled)
#         1    0.000    0.000    0.000    0.000 gfile.py:667(__init__)
#        10    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getDeviceCount}
#        26    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 typing.py:146(_type_check)
#         1    0.000    0.000    0.000    0.000 {method 'strftime' of 'datetime.date' objects}
#         2    0.000    0.000    0.000    0.000 posixpath.py:71(join)
#        13    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 graphs.py:19(is_current_stream_capturing)
#        22    0.000    0.000    0.000    0.000 utils.py:112(__format__)
#         6    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#         1    0.000    0.000    0.000    0.000 std.py:686(_decr_instances)
#         1    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#         1    0.000    0.000    0.001    0.001 _monitor.py:30(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method fromtimestamp}
#         8    0.000    0.000    0.000    0.000 typing.py:986(__setattr__)
#         1    0.000    0.000    0.002    0.002 writer.py:54(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:89(as_str_any)
#         2    0.000    0.000    0.001    0.000 std.py:1265(close)
#         1    0.000    0.000    0.000    0.000 context.py:70(RLock)
#         1    0.000    0.000    0.000    0.000 std.py:90(__init__)
#        24    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        26    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         1    0.000    0.000    0.000    0.000 storage.py:248(_dtype_to_storage_type_map)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:63(__iter__)
#        10    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        20    0.000    0.000    0.000    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#        29    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 typing.py:483(Union)
#        50    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 typing.py:1016(__init__)
#         1    0.000    0.000    0.001    0.001 event_file_writer.py:140(__init__)
#        20    0.000    0.000    0.000    0.000 __init__.py:89(annotate)
#         1    0.000    0.000    0.000    0.000 std.py:679(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 queue.py:34(__init__)
#         3    0.000    0.000    0.001    0.000 queue.py:79(join)
#         1    0.000    0.000    0.000    0.000 functools.py:393(__get__)
#         1    0.000    0.000    0.000    0.000 std.py:116(create_mp_lock)
#         1    0.000    0.000    0.000    0.000 random.py:128(seed)
#         1    0.000    0.000    0.000    0.000 os.py:200(makedirs)
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2989(_collect_type_vars)
#        57    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:86(add)
#         1    0.000    0.000    0.000    0.000 tempfile.py:153(__next__)
#         2    0.000    0.000    0.000    0.000 gfile.py:72(get_filesystem)
#         4    0.000    0.000    0.000    0.000 record_writer.py:42(flush)
#         1    0.000    0.000    0.000    0.000 __init__.py:7(_make_name)
#        24    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_schema}
#         1    0.000    0.000    0.000    0.000 random.py:519(<listcomp>)
#         1    0.000    0.000    0.001    0.001 std.py:438(status_printer)
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:218(__init__)
#         1    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#         2    0.000    0.000    0.000    0.000 ipkernel.py:768(init_closure)
#        10    0.000    0.000    0.000    0.000 _foreach_utils.py:27(<listcomp>)
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:34(get)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:2954(_has_generic_or_protocol_as_origin)
#        22    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 posixpath.py:100(split)
#         1    0.000    0.000    0.000    0.000 util.py:171(register_after_fork)
#         1    0.000    0.000    0.000    0.000 utils.py:213(__init__)
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:196(close)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#         1    0.000    0.000    0.000    0.000 typing.py:523(Optional)
#         1    0.000    0.000    0.000    0.000 typing.py:664(__init__)
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:238(stop)
#         1    0.000    0.000    0.000    0.000 random.py:506(choices)
#         3    0.000    0.000    0.000    0.000 typing.py:137(_type_convert)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#        13    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#        11    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 serialization.py:243(__enter__)
#         2    0.000    0.000    0.000    0.000 threading.py:782(_newname)
#         1    0.000    0.000    0.000    0.000 utils.py:347(<listcomp>)
#         1    0.000    0.000    0.000    0.000 gfile.py:206(makedirs)
#         1    0.000    0.000    0.000    0.000 gfile.py:901(makedirs)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:111(remove)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        13    0.000    0.000    0.000    0.000 typing.py:705(__eq__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         3    0.000    0.000    0.001    0.000 event_file_writer.py:119(flush)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#         3    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         2    0.000    0.000    0.000    0.000 threading.py:1301(_make_invoke_excepthook)
#         4    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         1    0.000    0.000    0.000    0.000 record_writer.py:45(close)
#         1    0.000    0.000    0.000    0.000 writer.py:1202(close)
#        20    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 writer.py:1192(flush)
#         4    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         1    0.000    0.000    0.000    0.000 synchronize.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:267(_remove_dups_flatten)
#       2/1    0.000    0.000    0.000    0.000 typing.py:401(__getitem__)
#         2    0.000    0.000    0.000    0.000 typing.py:1902(get_origin)
#         8    0.000    0.000    0.000    0.000 typing.py:935(_is_dunder)
#         1    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#        13    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         2    0.000    0.000    0.000    0.000 writer.py:145(flush)
#         1    0.000    0.000    0.000    0.000 threading.py:1064(join)
#         1    0.000    0.000    0.000    0.000 __init__.py:37(as_bytes)
#         2    0.000    0.000    0.000    0.000 std.py:1286(fp_write)
#         5    0.000    0.000    0.000    0.000 gfile.py:814(flush)
#         2    0.000    0.000    0.000    0.000 typing_extensions.py:2976(_is_unpacked_typevartuple)
#        10    0.000    0.000    0.000    0.000 optimizer.py:249(_optimizer_step_code)
#         1    0.000    0.000    0.000    0.000 random.py:119(__init__)
#         3    0.000    0.000    0.000    0.000 threading.py:1183(daemon)
#         1    0.000    0.000    0.000    0.000 __init__.py:61(as_text)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:266(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#         2    0.000    0.000    0.000    0.000 typing_extensions.py:154(_should_collect_from_parameters)
#         2    0.000    0.000    0.000    0.000 typing.py:714(__hash__)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:1198(daemon)
#         3    0.000    0.000    0.000    0.000 typing.py:515(<genexpr>)
#         1    0.000    0.000    0.000    0.000 typing.py:947(__init__)
#         1    0.000    0.000    0.000    0.000 weakref.py:348(__new__)
#         1    0.000    0.000    0.000    0.000 weakref.py:353(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:253(_deduplicate)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         8    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 context.py:237(get_context)
#         1    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 gfile.py:831(close)
#         3    0.000    0.000    0.000    0.000 typing.py:1022(<genexpr>)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         2    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         6    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 std.py:682(<setcomp>)
#         1    0.000    0.000    0.000    0.000 writer.py:152(close)
#         1    0.000    0.000    0.000    0.000 queue.py:206(_init)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         8    0.000    0.000    0.000    0.000 {built-in method math.floor}
#         1    0.000    0.000    0.000    0.000 writer.py:80(get_logdir)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         1    0.000    0.000    0.000    0.000 std.py:1147(__del__)
#         1    0.000    0.000    0.000    0.000 iostream.py:364(fileno)
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:127(close)
#         1    0.000    0.000    0.000    0.000 typing.py:380(__repr__)
#         2    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         1    0.000    0.000    0.000    0.000 record_writer.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 std.py:98(<listcomp>)
#         1    0.000    0.000    0.000    0.000 context.py:197(get_start_method)
#         3    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 event_file_writer.py:102(get_logdir)
#         2    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#         1    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 std.py:1301(<lambda>)

# %%
# Let's have a look at the loss over epochs:

df = pd.DataFrame(vi.losses_hist)
df.plot(logy=True)
# Out:
# <Axes: >

# %%
# We can load the best model to check the results
flow.load_state_dict(vi.best_estimator_state_dict)
# Out:
# <All keys matched successfully>

# %%
# Plot the final flow posterior approximator and compare it to the real parameters:
samples = flow.sample(50000)[0].cpu().detach().numpy()

pygtc.plotGTC([samples], truths=true_parameters.cpu().numpy(), figureSize=10, priors=[(-2, 1) for i in range(3)],
              paramRanges=[(-2, 1) for i in range(3)], paramNames=[r"$\gamma$", r"$\rho$", "initial_fraction_infected"])

# %%
# compare the predictions to the synthetic data:

f, ax = plt.subplots()

for i in range(25):
    with torch.no_grad():
        sim_sir = model((flow.sample(1)[0][0]))
    ax.plot(sim_sir[1].cpu().numpy(), color = "C0", alpha=0.5)
    ax.plot(sim_sir[2].cpu().numpy(), color = "C1", alpha=0.5)
    
ax.plot([], [], color = "C0", label = "predicted infected")
ax.plot([], [], color = "C1", label = "predicted recovered")
ax.plot(true_infected.cpu(), color = "black", linewidth=2, label = "data infected")
ax.plot(true_recovered.cpu(), color = "black", linewidth=2, label = "data recovered", linestyle="--")

ax.legend()
